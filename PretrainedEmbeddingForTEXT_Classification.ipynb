# %% [markdown]
# <a href="https://colab.research.google.com/github/rexindustries/introduction_to_NLP/blob/master/PretrainedEmbeddingForTEXT_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Let's Keep it Simple
#
# # Using pretrained embedding from tensorflow_hub to handle imdb_review dataset

# %%
# importing usefull libraries
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import pandas as pd
import tensorflow_hub as hub

# %% [markdown]
# # loading the embedding layer

# %%
model = tf.keras.Sequential([
                             hub.KerasLayer("https://tfhub.dev/google/tf2-preview/nnlm-en-dim50/1",
                                            dtype=tf.string, input_shape=[], output_shape=[50]), # in this case this layer encodes each string as a 50-dimenion vector
                             tf.keras.layers.Dense(128, activation='relu'),
                             tf.keras.layers.Dense(1, activation='sigmoid')

])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# # Load the data

# %%
datasets, info = tfds.load("imdb_reviews", as_supervised=True, with_info=True)
train_size = info.splits['train'].num_examples
batch_size = 32
train_set = datasets['train'].batch(batch_size).prefetch(1)
history = model.fit(train_set, epochs=5)
# Out:
# ...
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteHYTF4C/imdb_reviews-train.tfrecord
# ...
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteHYTF4C/imdb_reviews-test.tfrecord
# ...
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteHYTF4C/imdb_reviews-unsupervised.tfrecord
# ...
# WARNING:absl:Dataset is using deprecated text encoder API which will be removed soon. Please use the plain_text version of the dataset and migrate to `tensorflow_text`.
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# Epoch 1/5
# 782/782 [==============================] - 4s 6ms/step - loss: 0.5479 - accuracy: 0.7242
# Epoch 2/5
# 782/782 [==============================] - 4s 6ms/step - loss: 0.5141 - accuracy: 0.7486
# Epoch 3/5
# ...
